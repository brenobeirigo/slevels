# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(20,10))
df = pd.read_csv("fvtimes4.csv", sep=" ")
df2 = pd.read_csv("loadRV.csv", sep=" ")
# df.columns = ["Requests", "Serial", "Parallel1", "Parallel2", "Looping", "Method"]
(df[1:]/100000000).plot(ax=ax)
#_ =  plt.xticks(np.arange(len(df)), df.iloc[:,0])
#plt.ylim(0, 1000000000)

df.describe()
# Out:
#                req            t1            t2            t3            t4  \
# count   187.000000  1.870000e+02  1.870000e+02  1.870000e+02  1.870000e+02
# mean    655.957219  4.095475e+08  2.412538e+08  1.757864e+08  4.229006e+08
# std     466.495039  3.224657e+08  1.956052e+08  1.488974e+08  3.399073e+08
# min       0.000000  6.500000e+03  3.200000e+03  2.400000e+03  1.000000e+02
# 25%       0.000000  2.985000e+04  1.810000e+04  5.750000e+03  6.000000e+02
# 50%     981.000000  5.091758e+08  2.720472e+08  1.832110e+08  5.092761e+08
# 75%    1024.500000  6.617347e+08  4.175677e+08  3.022974e+08  6.781764e+08
# max    1122.000000  1.531674e+09  6.008307e+08  7.343399e+08  1.361781e+09
#
#                  t5
# count  1.870000e+02
# mean   1.502359e+08
# std    1.308279e+08
# min    1.200000e+03
# 25%    3.250000e+03
# 50%    1.678136e+08
# 75%    2.422469e+08
# max    7.714779e+08

# %%
df2 = pd.read_csv("loadRVgraph.csv", sep=" ")
df2
# Out:
#    req  loadTime
# 0    0    604300
# 1   92    181800
# 2  182    201400
# 3  262    118800
# 4  338    205500
# 5  411    177900
# 6  480    169300
# 7  566    174000

# %%
fig, ax = plt.subplots(figsize=(10,5))
df = pd.read_csv("rv2.csv", sep=" ")
df.plot(ax=ax)
#_ =  plt.xticks(np.arange(len(df)), df.iloc[:,0])
plt.ylim(0, 200000000)
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'old'}>,
#         <AxesSubplot:title={'center':'new'}>],
#        [<AxesSubplot:title={'center':'newer'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
df_best_visit = pd.read_csv("bestvisit3.csv", sep=" ")

# %%
df_best_visit[["3","2","1"]]= df_best_visit[["3","2","1"]]/100000000
df_best_visit.boxplot(column=["3","2","1"])
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# set a grey background (use sns.set_theme() if seaborn version 0.11.0 or above) 
sns.set(style="darkgrid")
df = sns.load_dataset("iris")

sns.histplot(data=df_best_visit, x="3", color="skyblue", label="3", kde=True)
sns.histplot(data=df_best_visit, x="2", color="red", label="2", kde=True)
sns.histplot(data=df_best_visit, x="1", color="green", label="1", kde=True)

plt.legend() 
plt.show()

# %%
df_best_visit.describe()
# Out:
#                  req              3              2              1
# count  266624.000000  266624.000000  266624.000000  266624.000000
# mean        2.589707       0.000457       0.000785       0.011213
# std         0.784356       0.002015       0.002235       0.034681
# min         1.000000       0.000003       0.000004       0.000008
# 25%         2.000000       0.000014       0.000027       0.000068
# 50%         3.000000       0.000104       0.000177       0.001482
# 75%         3.000000       0.000151       0.000266       0.002022
# max         4.000000       0.692342       0.186063       1.387710
