# %% [markdown]
# # Rebalance instances

# %% [markdown]
# ### 1) Overall configurations

# %%
import os
import os.path
import pandas as pd
from pprint import pprint

# Root
root_path = os.getcwd().replace("\\","/")

# Instance settings
# What is the best simulation.rebalancing policy?
# instance_settings_path = "C:/Users/LocalAdmin/IdeaProjects/slevels/src/main/resources/simulation.rebalancing/instance_settings_test_rebalancing.json"
# label = "reb_policy"

# Is it better to order the users per class?
instance_settings_path = "C:/Users/LocalAdmin/IdeaProjects/slevels/src/main/resources/week/service_denial_ABC.json"
label = "deny_comparison_b1_x_b2_x_sortclasses"

# Data translation
dict_sl_status = {"MET":"Shortest", "UNMET":"Extended"}
dict_sq_class = {"A":"Business", "B":"Standard", "C":"Low-cost"}
dict_service = {"FLEET":"Company-owned", "FREELANCE":"Third-party"}
category_segmentation = pd.api.types.CategoricalDtype(categories=["Business", "Standard", "Low-cost"], ordered=True)
category_fleet = pd.api.types.CategoricalDtype(categories=["Company-owned", "Third-party"], ordered=True)
category_status = pd.api.types.CategoricalDtype(categories=["Shortest", "Extended"], ordered=True)

# %% [markdown]
# ### 2) Loading the instance data

# %%
import json

def load_json(path):
    """Read json file and return dictionary"""

    # Add .json to the end of file if needed
    if path.find(".json") < 0:
        path = path + ".json"

    # Read JSON file
    with open(path) as data_file:
        data_loaded = json.load(data_file)

    return data_loaded

instances_dic = load_json(instance_settings_path)

# Folder where results will be saved
result_folder = instances_dic["result_folder"]
request_log_folder = result_folder + "/request_track"

# Folder where instances are located
instances_folder = instances_dic["instances_folder"]

# File name aggregated data
instance_name = instances_dic["instance_name"]


print("########### INSTANCE SETTINGS ##################################################")
pprint(instances_dic)
# Out:
# ########### INSTANCE SETTINGS ##################################################
# {'generate_test_cases': True,
#  'instance_description': 'Showing simulation.rebalancing superiority compared with no '
#                          'rebalance',
#  'instance_name': 'rebalancingSettings',
#  'instances_folder': 'C:/Users/LocalAdmin/IdeaProjects/slevels/instance_output/rebalancing_settings_4/',
#  'labels': {'BA': 'batch_duration',
#             'CD': 'contract_duration',
#             'CS': 'customer_segmentation',
#             'CT': 'clear_target_list_every_round',
#             'ID': 'instance_description',
#             'IF': 'initial_fleet',
#             'IN': 'instance_name',
#             'MC': 'max_capacity',
#             'MO': 'allow_many_to_one',
#             'MR': 'max_requests',
#             'RE': 'rebalance',
#             'RT': 'reinsert_targets',
#             'SD': 'allow_service_deterioration',
#             'SR': 'service_rate',
#             'ST': 'simulation_time',
#             'UR': 'allow_urgent_relocation',
#             'VH': 'allow_vehicle_hiring'},
#  'rebalancing_config': {'allow_many_to_one': [False, True],
#                         'allow_urgent_relocation': [False, True],
#                         'clear_target_list_every_round': [False, True],
#                         'reinsert_targets': [False, True]},
#  'result_folder': 'C:/Users/LocalAdmin/IdeaProjects/slevels/instance_output/rebalancing_settings_4/',
#  'scenario_config': {'allow_service_deterioration': [False],
#                      'allow_vehicle_creation': [False],
#                      'allow_vehicle_hiring': [False],
#                      'batch_duration': [30],
#                      'contract_duration': [86400],
#                      'customer_segmentation': {'A': {'A': 1, 'B': 0, 'C': 0},
#                                                'AA': {'A': 0.68,
#                                                       'B': 0.16,
#                                                       'C': 0.16},
#                                                'B': {'A': 0, 'B': 1, 'C': 0},
#                                                'BB': {'A': 0.16,
#                                                       'B': 0.68,
#                                                       'C': 0.16},
#                                                'C': {'A': 0, 'B': 0, 'C': 1},
#                                                'CC': {'A': 0.16,
#                                                       'B': 0.16,
#                                                       'C': 0.68}},
#                      'initial_fleet': [1000],
#                      'max_capacity': [4],
#                      'max_requests': [1000],
#                      'rebalance': [True],
#                      'service_level': {'A': {'pk_delay': 180,
#                                              'sharing_preference': 0,
#                                              'trip_delay': 180},
#                                        'B': {'pk_delay': 300,
#                                              'sharing_preference': 1,
#                                              'trip_delay': 600},
#                                        'C': {'pk_delay': 600,
#                                              'sharing_preference': 1,
#                                              'trip_delay': 900}},
#                      'service_rate': {'S1': {'A': 1, 'B': 0.9, 'C': 0.8}},
#                      'time_horizon': [86400]}}

# %% [markdown]
# ### Get settings from instance name

# %% [markdown]
# E.g.:
#
# * Input = `IN-instanceName_BA-30_TH-86400_MR-1000_IF-1000_MC-06_CD-3600-SR-S1_CS-AA_SD_VH_MO_RT_CT_UR`
#
# * Output =
# {allow_many_to_one: True,
# allow_service_deterioration: True,
# allow_urgent_relocation: True,
# allow_vehicle_hiring: True,
# batch_duration: 30,
# clear_target_list_every_round: True,
# contract_duration: 3600,
# customer_segmentation: AA,
# initial_fleet: 1000,
# max_capacity: 06,
# max_requests: 1000,
# reinsert_targets: True,
# time_horizon: 86400}

# %%
def get_instance_settings(file_name):
    """ Read file name and return instance settings.
    E.g.:
     Input = IN-instanceName_BA-30_TH-86400_MR-1000_IF-1000_MC-06_CD-3600-SR-S1_CS-AA_SD_VH_MO_RT_CT_UR
     Output = {'allow_many_to_one': True,
                'allow_service_deterioration': True,
                'allow_urgent_relocation': True,
                'allow_vehicle_hiring': True,
                'batch_duration': '30',
                'clear_target_list_every_round': True,
                'contract_duration': '3600',
                'customer_segmentation': 'AA',
                'initial_fleet': '1000',
                'max_capacity': '06',
                'max_requests': '1000',
                'reinsert_targets': True,
                'time_horizon': '86400'}
    """
    label_setting_dic = instances_dic["labels"]
    
    # print(file_name)
        
    # E.g., ['BA-30', 'TH-86400', 'MR-1000', 'IF-1000', 'MC-06', 'CD-3600-SR-S1', 'CS-AA', 'SD', 'VH', 'MO', 'RT', 'CT', 'UR']
    file_instances = file_name.split("_")

    instance_settings = dict()

    for e in file_instances:
        
        if e in label_setting_dic.keys():
            # E.g., e =  SD
            k = label_setting_dic[e]
            # E.g., k = allow_service_deterioration
            instance_settings[k] = True
            
        else:
            # E.g., lv = ["BA", "30"]
            lv  = e.split('-')
            # E.g., e2 = BA
            e2 = lv[0]
            # E.g., k = batch_duration
            k2 = label_setting_dic[e2]
            
            if len(lv) > 1:
                 # E.g., v = '30'
                v = lv[1]
                instance_settings[k2] = v
            else:
                # label is not in instance name = False
                instance_settings[k] = False

    return instance_settings

# %% [markdown]
# ### Aggregate results (folder round_track)
#
# Instance fields in `round_track` folder. Every line is a snapshot of a simulation round of 30 seconds (first column is round `timestamp`):
#
# #### Request status per round
# * `waiting`
# * `finished`
# * `denied`
# * `n_requests`
#
# #### Freelance vehicles per round
# * `hired_vehicles`
# * `deactivated_vehicles`
#
# #### Vehicle status per round
# * `active_vehicles`
# * `enroute_count`
# * `parked_vehicles`
# * `origin_vehicles`
# * `simulation.rebalancing`
# * `stopped_rebalancing`
# * `idle`
# * `picking_up`
# * `O1,O2,O3,O4`
# * `V1,V2,V3,V4`
# * `distance_traveled_cruising`
# * `distance_traveled_loaded`
# * `distance_traveled_rebalancing`
# * `run_time`
#
# #### Vehicle status per round (seats)
# * `seat_count`
# * `picking_up_seats`
# * `rebalancing_seats`
# * `empty_seats`
# * `total_capacity`
#
# #### Service quality
# * `pk_delay`
# * `total_delay`
# * `A_pk,A_dp,A_count,A_unmet_slevels`
# * `B_pk,B_dp,B_count,B_unmet_slevels`
# * `C_pk,C_dp,C_count,C_unmet_slevels`

# %%
import pandas as pd

def get_results_dic(path_experiment, name_experiment):
    
    # Load results
    experiment_file = "{}round_track/{}.csv".format(path_experiment, name_experiment)
    
    # print("Processing experiment file '{}'".format(experiment_file))
   

    df = pd.read_csv(experiment_file, index_col="timestamp",  parse_dates = True)

    # Number of requests
    total_requests = df["n_requests"].sum()
    serviced = df["finished"][-1]
    denied = df["denied"][-1]
    
    # Service quality
    sq_classes = ["A", "B", "C"]
    sq_settings = ["pk", "dp", "count", "unmet_slevels"]
    # e.g., ['A_pk', 'A_dp', 'A_count', 'A_unmet_slevels', 'B_pk', 'B_dp', 'B_count', 'B_unmet_slevels', 'C_pk', 'C_dp', 'C_count', 'C_unmet_slevels']
    sq_user_labels = ["{}_{}".format(sq_class, sq_setting) for sq_class in sq_classes for sq_setting in sq_settings]
    sq_user_dic = {l:df[l][-1] for l in sq_user_labels}
    
    # Distance traveled
    distance_cruising = df["distance_traveled_cruising"][-1]
    distance_loaded = df["distance_traveled_loaded"][-1]
    distance_rebalancing = df["distance_traveled_rebalancing"][-1]
    distance_total = distance_cruising + distance_loaded + distance_rebalancing

    # Pickup
    avg_pk_delay = df["pk_delay"].mean()
    avg_ride_delay = df["total_delay"].mean()

    # Separate occupancy labels (e.g., O1, O2, O3, etc.)
    occupancy_labels = [col for col in list(df) if 'O' in col]
    status_labels = [ "idle", "picking_up"] + occupancy_labels
    
    # Get fleet makeup
    fleet_makeup_labels = [col for col in list(df) if 'V' in col]
    fleet_makeup = {mk:df[mk][-1] for mk in fleet_makeup_labels}
    total_seats = {"seats_" + k:int(k[1:]) * v for k,v in fleet_makeup.items()}
    total_seats["total_seats"] = sum(total_seats.values())
    #max_hired = df["hired"].max()

    # Runtime
    total_runtime = df["run_time"].sum()
    
    # Dictionary of agreggate data
    dic_agreggate_data = {"serviced": "{:.2%}".format(serviced/total_requests),
                          "denied": "{:.2%}".format(denied/total_requests),
                          #'max_hired': max_hired,
                          "total_requests": total_requests,
                          "avg_pk_delay": "{:.2f}".format(avg_pk_delay),
                          "avg_ride_delay": "{:.2f}".format(avg_ride_delay),
                          "total_runtime": "{:.2f}".format(total_runtime/1000/60),
                          "distance_cruising": "{:.2%}".format(distance_cruising/distance_total),
                          "distance_loaded": "{:.2%}".format(distance_loaded/distance_total),
                          "distance_rebalancing": "{:.2%}".format(distance_rebalancing/distance_total),
                          "distance_total": distance_total//1000}
    
    # All data
    dic_ag = {**dic_agreggate_data, **fleet_makeup}
    dic_ag = {**dic_ag, **total_seats}
    dic_ag = {**dic_ag, **sq_user_dic}

    return dic_ag

# %% [markdown]
# ### Aggregate results (folder request_track)
#
# * `earliest`
# * `id` = 1, 2, 3, ..., #USERS
# * `class` = A, B, C
# * `pk_delay`
# * `ride_delay`
# * `pk_time`
# * `dp_time`
# * `id_from` = Network id
# * `id_to` = Network id
# * `dist` = trip(id_from, id_to) in seconds
# * `service` = {FLEET, FREELANCE}
# * `service_level` = {MET, UNMET}

# %%
import pandas as pd
from pprint import pprint

def get_request_track_dic(path_experiment, name_experiment):
    
    # Load results
    experiment_file = "{}request_track/{}.csv".format(path_experiment, name_experiment)
    
    # print("Processing experiment file '{}'".format(experiment_file))
    df = pd.read_csv(experiment_file, index_col="earliest",  parse_dates = True)
    
    aggfunc = {"pk_delay" : ['mean', 'count', 'max']}
    
    dfp = df.pivot_table(index="class", columns="service_level", aggfunc=aggfunc, values=["pk_delay"])

    return dfp

# %%
import pandas as pd
from pprint import pprint

def get_request_track_dic(path_experiment, name_experiment):
    
    # Load results
    experiment_file = "{}request_track/{}.csv".format(path_experiment, name_experiment)
    
    # print("Processing experiment file '{}'".format(experiment_file))
    df = pd.read_csv(experiment_file, index_col="earliest",  parse_dates = True)
    
    aggfunc = {"pk_delay" : ['mean', 'count', 'max']}
    
    # Also can be done with pivot table
    df_pivot = df.pivot_table(index="class", columns="service_level", aggfunc=aggfunc, values=["pk_delay", "id_from"])


    service_count = df['service'].value_counts().to_dict()
    class_count = df['class'].value_counts().to_dict()
    
    # How many users had their service levels fulfilled (MET)? How many had their service levels deteriorated, or have been rejected (UNMET)?
    service_level = df['service_level'].value_counts().to_dict()  
    
    # 
    service_quality_dic = {'A':{'MET': {'Avg.':None, 'Max.':None, 'Count':None}, 'UNMET': {'Avg.':None, 'Max.':None, 'Count':None}},
                           'B':{'MET': {'Avg.':None, 'Max.':None, 'Count':None}, 'UNMET': {'Avg.':None, 'Max.':None, 'Count':None}},
                           'C':{'MET': {'Avg.':None, 'Max.':None, 'Count':None}, 'UNMET': {'Avg.':None, 'Max.':None, 'Count':None}}}
 
    for sq_class in ['A', 'B', 'C']:
        for service_level in ["MET", "UNMET"]:
            filter_sq_sl = (df['class'] == sq_class) & (df['service_level'] == service_level)
            service_quality_dic[sq_class][service_level]['Max.'] = df.loc[filter_sq_sl]["pk_delay"].max()
            service_quality_dic[sq_class][service_level]['Avg.'] = df.loc[filter_sq_sl]["pk_delay"].mean()
            service_quality_dic[sq_class][service_level]['Count'] = df.loc[filter_sq_sl]["pk_delay"].count()
    
    # How many vehicles (freelance or from initial fleet) serviced each user (considering class and service quality status, that is, MET or UNMET)
    fleet_settings_dic = {sq_class:{service_level:df.loc[(df['class']==sq_class) & 
                                                         (df['service_level']==service_level)]["service"].value_counts().to_dict()
                                                   
                                    for service_level in  ["MET", "UNMET"]}
                          for sq_class in ['A', 'B', 'C']}
    
    dic_request_track = {"service_levels":service_quality_dic,
                          "fleet_settings":fleet_settings_dic}
    
    return dic_request_track

# %% [markdown]
# ### Processing single instance

# %% [raw]
# # Processing instance
#
# file_name = "IN-HIRING_BA-30_ST-600_MR-1000_IF-10_MC-4_CS-AA_CD-0_SR-S1_VH_SD_RE_CT_RT_UR"
#
# # Get instance settings according to file name
# instance_settings = get_instance_settings(file_name)
#
# # Filtered instance settings
# instance_settings = {key:value for key,value in instance_settings.items() if key in ["customer_segmentation",  "service_rate", "contract_duration"]}
# print("\n##### Instance settings ################################################")
# pprint(instance_settings)
#
# # Round track data
# round_track_dic = get_results_dic(instances_folder, file_name)
# print("\n##### Round track ######################################################")
# pprint(round_track_dic)
#
# # Request track data
# request_track_dic = get_request_track_dic(instances_folder, file_name)
# print("\n##### Request track ####################################################")
# pprint(request_track_dic)

# %%
import pandas as pd

def get_aggregate_request_dic(path_experiment, name_experiment):
    
    # Load results
    experiment_file = "{}request_track/{}.csv".format(path_experiment, name_experiment)
    
   
    df = pd.read_csv(experiment_file, index_col = "earliest",  parse_dates = True)

    return df

# %% [markdown]
# ### Processing all instances in folder

# %%
# Get all instances in folder
instance_file_names = os.listdir(request_log_folder)
instance_file_names = [i for i in instance_file_names if instances_dic['instance_name'] in i]

# Instance Info (key = instance name)
dic_all_instance_settings = dict()
dic_all_round_track = dict()
dic_all_request_track = dict()

print("Reading files in folder:", request_log_folder)
for file_name in instance_file_names:
    
    instance, extension = file_name.split(".")
    print("  - Processing", instance)
    
    # Instance settings
    instance_settings_dic = get_instance_settings(instance)
    round_track_agg_dic = get_results_dic(instances_folder, instance)
    request_track_agg_dic = get_request_track_dic(instances_folder, instance)
    
    # Get aggregated results
    dic_all_round_track[instance] = round_track_agg_dic
    dic_all_request_track[instance] = request_track_agg_dic
    dic_all_instance_settings[instance] = instance_settings_dic
# Out:
# Reading files in folder: C:/Users/LocalAdmin/IdeaProjects/slevels/instance_output/rebalancing_settings_4//request_track
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE_CT
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE_CT_MO
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE_CT_MO_RT
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE_CT_MO_RT_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE_CT_MO_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE_CT_RT
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE_CT_RT_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE_CT_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE_MO
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE_MO_RT
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE_MO_RT_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE_MO_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE_RT
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE_RT_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE_CT
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE_CT_MO
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE_CT_MO_RT
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE_CT_MO_RT_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE_CT_MO_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE_CT_RT
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE_CT_RT_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE_CT_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE_MO
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE_MO_RT
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE_MO_RT_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE_MO_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE_RT
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE_RT_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-BB_RE
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-BB_RE_CT
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-BB_RE_CT_MO
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-BB_RE_CT_MO_RT
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-BB_RE_CT_MO_RT_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-BB_RE_CT_MO_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-BB_RE_CT_RT
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-BB_RE_CT_RT_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-BB_RE_CT_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-BB_RE_MO
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-BB_RE_MO_RT
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-BB_RE_MO_RT_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-BB_RE_MO_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-BB_RE_RT
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-BB_RE_RT_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-BB_RE_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-B_RE
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-B_RE_CT
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-B_RE_CT_MO
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-B_RE_CT_MO_RT
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-B_RE_CT_MO_RT_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-B_RE_CT_MO_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-B_RE_CT_RT
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-B_RE_CT_RT_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-B_RE_CT_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-B_RE_MO
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-B_RE_MO_RT
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-B_RE_MO_RT_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-B_RE_MO_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-B_RE_RT
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-B_RE_RT_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-B_RE_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-CC_RE
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-CC_RE_CT
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-CC_RE_CT_MO
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-CC_RE_CT_MO_RT
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-CC_RE_CT_MO_RT_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-CC_RE_CT_MO_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-CC_RE_CT_RT
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-CC_RE_CT_RT_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-CC_RE_CT_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-CC_RE_MO
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-CC_RE_MO_RT
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-CC_RE_MO_RT_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-CC_RE_MO_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-CC_RE_RT
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-CC_RE_RT_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-CC_RE_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-C_RE
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-C_RE_CT
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-C_RE_CT_MO
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-C_RE_CT_MO_RT
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-C_RE_CT_MO_RT_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-C_RE_CT_MO_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-C_RE_CT_RT
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-C_RE_CT_RT_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-C_RE_CT_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-C_RE_MO
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-C_RE_MO_RT
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-C_RE_MO_RT_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-C_RE_MO_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-C_RE_RT
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-C_RE_RT_UR
#   - Processing IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-C_RE_UR

# %%
print("Instance settings:")
pprint(dic_all_instance_settings)
# Out:
# Instance settings:
# {'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE': {'batch_duration': '30',
#                                                                          'customer_segmentation': 'AA',
#                                                                          'initial_fleet': '1000',
#                                                                          'instance_name': 'rebalancingSettings',
#                                                                          'max_capacity': '4',
#                                                                          'max_requests': '1000',
#                                                                          'rebalance': True,
#                                                                          'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE_CT': {'batch_duration': '30',
#                                                                             'clear_target_list_every_round': True,
#                                                                             'customer_segmentation': 'AA',
#                                                                             'initial_fleet': '1000',
#                                                                             'instance_name': 'rebalancingSettings',
#                                                                             'max_capacity': '4',
#                                                                             'max_requests': '1000',
#                                                                             'rebalance': True,
#                                                                             'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE_CT_MO': {'allow_many_to_one': True,
#                                                                                'batch_duration': '30',
#                                                                                'clear_target_list_every_round': True,
#                                                                                'customer_segmentation': 'AA',
#                                                                                'initial_fleet': '1000',
#                                                                                'instance_name': 'rebalancingSettings',
#                                                                                'max_capacity': '4',
#                                                                                'max_requests': '1000',
#                                                                                'rebalance': True,
#                                                                                'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE_CT_MO_RT': {'allow_many_to_one': True,
#                                                                                   'batch_duration': '30',
#                                                                                   'clear_target_list_every_round': True,
#                                                                                   'customer_segmentation': 'AA',
#                                                                                   'initial_fleet': '1000',
#                                                                                   'instance_name': 'rebalancingSettings',
#                                                                                   'max_capacity': '4',
#                                                                                   'max_requests': '1000',
#                                                                                   'rebalance': True,
#                                                                                   'reinsert_targets': True,
#                                                                                   'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE_CT_MO_RT_UR': {'allow_many_to_one': True,
#                                                                                      'allow_urgent_relocation': True,
#                                                                                      'batch_duration': '30',
#                                                                                      'clear_target_list_every_round': True,
#                                                                                      'customer_segmentation': 'AA',
#                                                                                      'initial_fleet': '1000',
#                                                                                      'instance_name': 'rebalancingSettings',
#                                                                                      'max_capacity': '4',
#                                                                                      'max_requests': '1000',
#                                                                                      'rebalance': True,
#                                                                                      'reinsert_targets': True,
#                                                                                      'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE_CT_MO_UR': {'allow_many_to_one': True,
#                                                                                   'allow_urgent_relocation': True,
#                                                                                   'batch_duration': '30',
#                                                                                   'clear_target_list_every_round': True,
#                                                                                   'customer_segmentation': 'AA',
#                                                                                   'initial_fleet': '1000',
#                                                                                   'instance_name': 'rebalancingSettings',
#                                                                                   'max_capacity': '4',
#                                                                                   'max_requests': '1000',
#                                                                                   'rebalance': True,
#                                                                                   'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE_CT_RT': {'batch_duration': '30',
#                                                                                'clear_target_list_every_round': True,
#                                                                                'customer_segmentation': 'AA',
#                                                                                'initial_fleet': '1000',
#                                                                                'instance_name': 'rebalancingSettings',
#                                                                                'max_capacity': '4',
#                                                                                'max_requests': '1000',
#                                                                                'rebalance': True,
#                                                                                'reinsert_targets': True,
#                                                                                'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE_CT_RT_UR': {'allow_urgent_relocation': True,
#                                                                                   'batch_duration': '30',
#                                                                                   'clear_target_list_every_round': True,
#                                                                                   'customer_segmentation': 'AA',
#                                                                                   'initial_fleet': '1000',
#                                                                                   'instance_name': 'rebalancingSettings',
#                                                                                   'max_capacity': '4',
#                                                                                   'max_requests': '1000',
#                                                                                   'rebalance': True,
#                                                                                   'reinsert_targets': True,
#                                                                                   'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE_CT_UR': {'allow_urgent_relocation': True,
#                                                                                'batch_duration': '30',
#                                                                                'clear_target_list_every_round': True,
#                                                                                'customer_segmentation': 'AA',
#                                                                                'initial_fleet': '1000',
#                                                                                'instance_name': 'rebalancingSettings',
#                                                                                'max_capacity': '4',
#                                                                                'max_requests': '1000',
#                                                                                'rebalance': True,
#                                                                                'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE_MO': {'allow_many_to_one': True,
#                                                                             'batch_duration': '30',
#                                                                             'customer_segmentation': 'AA',
#                                                                             'initial_fleet': '1000',
#                                                                             'instance_name': 'rebalancingSettings',
#                                                                             'max_capacity': '4',
#                                                                             'max_requests': '1000',
#                                                                             'rebalance': True,
#                                                                             'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE_MO_RT': {'allow_many_to_one': True,
#                                                                                'batch_duration': '30',
#                                                                                'customer_segmentation': 'AA',
#                                                                                'initial_fleet': '1000',
#                                                                                'instance_name': 'rebalancingSettings',
#                                                                                'max_capacity': '4',
#                                                                                'max_requests': '1000',
#                                                                                'rebalance': True,
#                                                                                'reinsert_targets': True,
#                                                                                'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE_MO_RT_UR': {'allow_many_to_one': True,
#                                                                                   'allow_urgent_relocation': True,
#                                                                                   'batch_duration': '30',
#                                                                                   'customer_segmentation': 'AA',
#                                                                                   'initial_fleet': '1000',
#                                                                                   'instance_name': 'rebalancingSettings',
#                                                                                   'max_capacity': '4',
#                                                                                   'max_requests': '1000',
#                                                                                   'rebalance': True,
#                                                                                   'reinsert_targets': True,
#                                                                                   'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE_MO_UR': {'allow_many_to_one': True,
#                                                                                'allow_urgent_relocation': True,
#                                                                                'batch_duration': '30',
#                                                                                'customer_segmentation': 'AA',
#                                                                                'initial_fleet': '1000',
#                                                                                'instance_name': 'rebalancingSettings',
#                                                                                'max_capacity': '4',
#                                                                                'max_requests': '1000',
#                                                                                'rebalance': True,
#                                                                                'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE_RT': {'batch_duration': '30',
#                                                                             'customer_segmentation': 'AA',
#                                                                             'initial_fleet': '1000',
#                                                                             'instance_name': 'rebalancingSettings',
#                                                                             'max_capacity': '4',
#                                                                             'max_requests': '1000',
#                                                                             'rebalance': True,
#                                                                             'reinsert_targets': True,
#                                                                             'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE_RT_UR': {'allow_urgent_relocation': True,
#                                                                                'batch_duration': '30',
#                                                                                'customer_segmentation': 'AA',
#                                                                                'initial_fleet': '1000',
#                                                                                'instance_name': 'rebalancingSettings',
#                                                                                'max_capacity': '4',
#                                                                                'max_requests': '1000',
#                                                                                'rebalance': True,
#                                                                                'reinsert_targets': True,
#                                                                                'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-AA_RE_UR': {'allow_urgent_relocation': True,
#                                                                             'batch_duration': '30',
#                                                                             'customer_segmentation': 'AA',
#                                                                             'initial_fleet': '1000',
#                                                                             'instance_name': 'rebalancingSettings',
#                                                                             'max_capacity': '4',
#                                                                             'max_requests': '1000',
#                                                                             'rebalance': True,
#                                                                             'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE': {'batch_duration': '30',
#                                                                         'customer_segmentation': 'A',
#                                                                         'initial_fleet': '1000',
#                                                                         'instance_name': 'rebalancingSettings',
#                                                                         'max_capacity': '4',
#                                                                         'max_requests': '1000',
#                                                                         'rebalance': True,
#                                                                         'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE_CT': {'batch_duration': '30',
#                                                                            'clear_target_list_every_round': True,
#                                                                            'customer_segmentation': 'A',
#                                                                            'initial_fleet': '1000',
#                                                                            'instance_name': 'rebalancingSettings',
#                                                                            'max_capacity': '4',
#                                                                            'max_requests': '1000',
#                                                                            'rebalance': True,
#                                                                            'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE_CT_MO': {'allow_many_to_one': True,
#                                                                               'batch_duration': '30',
#                                                                               'clear_target_list_every_round': True,
#                                                                               'customer_segmentation': 'A',
#                                                                               'initial_fleet': '1000',
#                                                                               'instance_name': 'rebalancingSettings',
#                                                                               'max_capacity': '4',
#                                                                               'max_requests': '1000',
#                                                                               'rebalance': True,
#                                                                               'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE_CT_MO_RT': {'allow_many_to_one': True,
#                                                                                  'batch_duration': '30',
#                                                                                  'clear_target_list_every_round': True,
#                                                                                  'customer_segmentation': 'A',
#                                                                                  'initial_fleet': '1000',
#                                                                                  'instance_name': 'rebalancingSettings',
#                                                                                  'max_capacity': '4',
#                                                                                  'max_requests': '1000',
#                                                                                  'rebalance': True,
#                                                                                  'reinsert_targets': True,
#                                                                                  'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE_CT_MO_RT_UR': {'allow_many_to_one': True,
#                                                                                     'allow_urgent_relocation': True,
#                                                                                     'batch_duration': '30',
#                                                                                     'clear_target_list_every_round': True,
#                                                                                     'customer_segmentation': 'A',
#                                                                                     'initial_fleet': '1000',
#                                                                                     'instance_name': 'rebalancingSettings',
#                                                                                     'max_capacity': '4',
#                                                                                     'max_requests': '1000',
#                                                                                     'rebalance': True,
#                                                                                     'reinsert_targets': True,
#                                                                                     'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE_CT_MO_UR': {'allow_many_to_one': True,
#                                                                                  'allow_urgent_relocation': True,
#                                                                                  'batch_duration': '30',
#                                                                                  'clear_target_list_every_round': True,
#                                                                                  'customer_segmentation': 'A',
#                                                                                  'initial_fleet': '1000',
#                                                                                  'instance_name': 'rebalancingSettings',
#                                                                                  'max_capacity': '4',
#                                                                                  'max_requests': '1000',
#                                                                                  'rebalance': True,
#                                                                                  'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE_CT_RT': {'batch_duration': '30',
#                                                                               'clear_target_list_every_round': True,
#                                                                               'customer_segmentation': 'A',
#                                                                               'initial_fleet': '1000',
#                                                                               'instance_name': 'rebalancingSettings',
#                                                                               'max_capacity': '4',
#                                                                               'max_requests': '1000',
#                                                                               'rebalance': True,
#                                                                               'reinsert_targets': True,
#                                                                               'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE_CT_RT_UR': {'allow_urgent_relocation': True,
#                                                                                  'batch_duration': '30',
#                                                                                  'clear_target_list_every_round': True,
#                                                                                  'customer_segmentation': 'A',
#                                                                                  'initial_fleet': '1000',
#                                                                                  'instance_name': 'rebalancingSettings',
#                                                                                  'max_capacity': '4',
#                                                                                  'max_requests': '1000',
#                                                                                  'rebalance': True,
#                                                                                  'reinsert_targets': True,
#                                                                                  'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE_CT_UR': {'allow_urgent_relocation': True,
#                                                                               'batch_duration': '30',
#                                                                               'clear_target_list_every_round': True,
#                                                                               'customer_segmentation': 'A',
#                                                                               'initial_fleet': '1000',
#                                                                               'instance_name': 'rebalancingSettings',
#                                                                               'max_capacity': '4',
#                                                                               'max_requests': '1000',
#                                                                               'rebalance': True,
#                                                                               'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE_MO': {'allow_many_to_one': True,
#                                                                            'batch_duration': '30',
#                                                                            'customer_segmentation': 'A',
#                                                                            'initial_fleet': '1000',
#                                                                            'instance_name': 'rebalancingSettings',
#                                                                            'max_capacity': '4',
#                                                                            'max_requests': '1000',
#                                                                            'rebalance': True,
#                                                                            'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE_MO_RT': {'allow_many_to_one': True,
#                                                                               'batch_duration': '30',
#                                                                               'customer_segmentation': 'A',
#                                                                               'initial_fleet': '1000',
#                                                                               'instance_name': 'rebalancingSettings',
#                                                                               'max_capacity': '4',
#                                                                               'max_requests': '1000',
#                                                                               'rebalance': True,
#                                                                               'reinsert_targets': True,
#                                                                               'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE_MO_RT_UR': {'allow_many_to_one': True,
#                                                                                  'allow_urgent_relocation': True,
#                                                                                  'batch_duration': '30',
#                                                                                  'customer_segmentation': 'A',
#                                                                                  'initial_fleet': '1000',
#                                                                                  'instance_name': 'rebalancingSettings',
#                                                                                  'max_capacity': '4',
#                                                                                  'max_requests': '1000',
#                                                                                  'rebalance': True,
#                                                                                  'reinsert_targets': True,
#                                                                                  'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE_MO_UR': {'allow_many_to_one': True,
#                                                                               'allow_urgent_relocation': True,
#                                                                               'batch_duration': '30',
#                                                                               'customer_segmentation': 'A',
#                                                                               'initial_fleet': '1000',
#                                                                               'instance_name': 'rebalancingSettings',
#                                                                               'max_capacity': '4',
#                                                                               'max_requests': '1000',
#                                                                               'rebalance': True,
#                                                                               'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE_RT': {'batch_duration': '30',
#                                                                            'customer_segmentation': 'A',
#                                                                            'initial_fleet': '1000',
#                                                                            'instance_name': 'rebalancingSettings',
#                                                                            'max_capacity': '4',
#                                                                            'max_requests': '1000',
#                                                                            'rebalance': True,
#                                                                            'reinsert_targets': True,
#                                                                            'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE_RT_UR': {'allow_urgent_relocation': True,
#                                                                               'batch_duration': '30',
#                                                                               'customer_segmentation': 'A',
#                                                                               'initial_fleet': '1000',
#                                                                               'instance_name': 'rebalancingSettings',
#                                                                               'max_capacity': '4',
#                                                                               'max_requests': '1000',
#                                                                               'rebalance': True,
#                                                                               'reinsert_targets': True,
#                                                                               'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-A_RE_UR': {'allow_urgent_relocation': True,
#                                                                            'batch_duration': '30',
#                                                                            'customer_segmentation': 'A',
#                                                                            'initial_fleet': '1000',
#                                                                            'instance_name': 'rebalancingSettings',
#                                                                            'max_capacity': '4',
#                                                                            'max_requests': '1000',
#                                                                            'rebalance': True,
#                                                                            'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-BB_RE': {'batch_duration': '30',
#                                                                          'customer_segmentation': 'BB',
#                                                                          'initial_fleet': '1000',
#                                                                          'instance_name': 'rebalancingSettings',
#                                                                          'max_capacity': '4',
#                                                                          'max_requests': '1000',
#                                                                          'rebalance': True,
#                                                                          'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-BB_RE_CT': {'batch_duration': '30',
#                                                                             'clear_target_list_every_round': True,
#                                                                             'customer_segmentation': 'BB',
#                                                                             'initial_fleet': '1000',
#                                                                             'instance_name': 'rebalancingSettings',
#                                                                             'max_capacity': '4',
#                                                                             'max_requests': '1000',
#                                                                             'rebalance': True,
#                                                                             'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-BB_RE_CT_MO': {'allow_many_to_one': True,
#                                                                                'batch_duration': '30',
#                                                                                'clear_target_list_every_round': True,
#                                                                                'customer_segmentation': 'BB',
#                                                                                'initial_fleet': '1000',
#                                                                                'instance_name': 'rebalancingSettings',
#                                                                                'max_capacity': '4',
#                                                                                'max_requests': '1000',
#                                                                                'rebalance': True,
#                                                                                'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-BB_RE_CT_MO_RT': {'allow_many_to_one': True,
#                                                                                   'batch_duration': '30',
#                                                                                   'clear_target_list_every_round': True,
#                                                                                   'customer_segmentation': 'BB',
#                                                                                   'initial_fleet': '1000',
#                                                                                   'instance_name': 'rebalancingSettings',
#                                                                                   'max_capacity': '4',
#                                                                                   'max_requests': '1000',
#                                                                                   'rebalance': True,
#                                                                                   'reinsert_targets': True,
#                                                                                   'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-BB_RE_CT_MO_RT_UR': {'allow_many_to_one': True,
#                                                                                      'allow_urgent_relocation': True,
#                                                                                      'batch_duration': '30',
#                                                                                      'clear_target_list_every_round': True,
#                                                                                      'customer_segmentation': 'BB',
#                                                                                      'initial_fleet': '1000',
#                                                                                      'instance_name': 'rebalancingSettings',
#                                                                                      'max_capacity': '4',
#                                                                                      'max_requests': '1000',
#                                                                                      'rebalance': True,
#                                                                                      'reinsert_targets': True,
#                                                                                      'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-BB_RE_CT_MO_UR': {'allow_many_to_one': True,
#                                                                                   'allow_urgent_relocation': True,
#                                                                                   'batch_duration': '30',
#                                                                                   'clear_target_list_every_round': True,
#                                                                                   'customer_segmentation': 'BB',
#                                                                                   'initial_fleet': '1000',
#                                                                                   'instance_name': 'rebalancingSettings',
#                                                                                   'max_capacity': '4',
#                                                                                   'max_requests': '1000',
#                                                                                   'rebalance': True,
#                                                                                   'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-BB_RE_CT_RT': {'batch_duration': '30',
#                                                                                'clear_target_list_every_round': True,
#                                                                                'customer_segmentation': 'BB',
#                                                                                'initial_fleet': '1000',
#                                                                                'instance_name': 'rebalancingSettings',
#                                                                                'max_capacity': '4',
#                                                                                'max_requests': '1000',
#                                                                                'rebalance': True,
#                                                                                'reinsert_targets': True,
#                                                                                'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-BB_RE_CT_RT_UR': {'allow_urgent_relocation': True,
#                                                                                   'batch_duration': '30',
#                                                                                   'clear_target_list_every_round': True,
#                                                                                   'customer_segmentation': 'BB',
#                                                                                   'initial_fleet': '1000',
#                                                                                   'instance_name': 'rebalancingSettings',
#                                                                                   'max_capacity': '4',
#                                                                                   'max_requests': '1000',
#                                                                                   'rebalance': True,
#                                                                                   'reinsert_targets': True,
#                                                                                   'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-BB_RE_CT_UR': {'allow_urgent_relocation': True,
#                                                                                'batch_duration': '30',
#                                                                                'clear_target_list_every_round': True,
#                                                                                'customer_segmentation': 'BB',
#                                                                                'initial_fleet': '1000',
#                                                                                'instance_name': 'rebalancingSettings',
#                                                                                'max_capacity': '4',
#                                                                                'max_requests': '1000',
#                                                                                'rebalance': True,
#                                                                                'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-BB_RE_MO': {'allow_many_to_one': True,
#                                                                             'batch_duration': '30',
#                                                                             'customer_segmentation': 'BB',
#                                                                             'initial_fleet': '1000',
#                                                                             'instance_name': 'rebalancingSettings',
#                                                                             'max_capacity': '4',
#                                                                             'max_requests': '1000',
#                                                                             'rebalance': True,
#                                                                             'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-BB_RE_MO_RT': {'allow_many_to_one': True,
#                                                                                'batch_duration': '30',
#                                                                                'customer_segmentation': 'BB',
#                                                                                'initial_fleet': '1000',
#                                                                                'instance_name': 'rebalancingSettings',
#                                                                                'max_capacity': '4',
#                                                                                'max_requests': '1000',
#                                                                                'rebalance': True,
#                                                                                'reinsert_targets': True,
#                                                                                'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-BB_RE_MO_RT_UR': {'allow_many_to_one': True,
#                                                                                   'allow_urgent_relocation': True,
#                                                                                   'batch_duration': '30',
#                                                                                   'customer_segmentation': 'BB',
#                                                                                   'initial_fleet': '1000',
#                                                                                   'instance_name': 'rebalancingSettings',
#                                                                                   'max_capacity': '4',
#                                                                                   'max_requests': '1000',
#                                                                                   'rebalance': True,
#                                                                                   'reinsert_targets': True,
#                                                                                   'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-BB_RE_MO_UR': {'allow_many_to_one': True,
#                                                                                'allow_urgent_relocation': True,
#                                                                                'batch_duration': '30',
#                                                                                'customer_segmentation': 'BB',
#                                                                                'initial_fleet': '1000',
#                                                                                'instance_name': 'rebalancingSettings',
#                                                                                'max_capacity': '4',
# ...
#                                                                            'customer_segmentation': 'C',
#                                                                            'initial_fleet': '1000',
#                                                                            'instance_name': 'rebalancingSettings',
#                                                                            'max_capacity': '4',
#                                                                            'max_requests': '1000',
#                                                                            'rebalance': True,
#                                                                            'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-C_RE_CT_MO': {'allow_many_to_one': True,
#                                                                               'batch_duration': '30',
#                                                                               'clear_target_list_every_round': True,
#                                                                               'customer_segmentation': 'C',
#                                                                               'initial_fleet': '1000',
#                                                                               'instance_name': 'rebalancingSettings',
#                                                                               'max_capacity': '4',
#                                                                               'max_requests': '1000',
#                                                                               'rebalance': True,
#                                                                               'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-C_RE_CT_MO_RT': {'allow_many_to_one': True,
#                                                                                  'batch_duration': '30',
#                                                                                  'clear_target_list_every_round': True,
#                                                                                  'customer_segmentation': 'C',
#                                                                                  'initial_fleet': '1000',
#                                                                                  'instance_name': 'rebalancingSettings',
#                                                                                  'max_capacity': '4',
#                                                                                  'max_requests': '1000',
#                                                                                  'rebalance': True,
#                                                                                  'reinsert_targets': True,
#                                                                                  'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-C_RE_CT_MO_RT_UR': {'allow_many_to_one': True,
#                                                                                     'allow_urgent_relocation': True,
#                                                                                     'batch_duration': '30',
#                                                                                     'clear_target_list_every_round': True,
#                                                                                     'customer_segmentation': 'C',
#                                                                                     'initial_fleet': '1000',
#                                                                                     'instance_name': 'rebalancingSettings',
#                                                                                     'max_capacity': '4',
#                                                                                     'max_requests': '1000',
#                                                                                     'rebalance': True,
#                                                                                     'reinsert_targets': True,
#                                                                                     'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-C_RE_CT_MO_UR': {'allow_many_to_one': True,
#                                                                                  'allow_urgent_relocation': True,
#                                                                                  'batch_duration': '30',
#                                                                                  'clear_target_list_every_round': True,
#                                                                                  'customer_segmentation': 'C',
#                                                                                  'initial_fleet': '1000',
#                                                                                  'instance_name': 'rebalancingSettings',
#                                                                                  'max_capacity': '4',
#                                                                                  'max_requests': '1000',
#                                                                                  'rebalance': True,
#                                                                                  'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-C_RE_CT_RT': {'batch_duration': '30',
#                                                                               'clear_target_list_every_round': True,
#                                                                               'customer_segmentation': 'C',
#                                                                               'initial_fleet': '1000',
#                                                                               'instance_name': 'rebalancingSettings',
#                                                                               'max_capacity': '4',
#                                                                               'max_requests': '1000',
#                                                                               'rebalance': True,
#                                                                               'reinsert_targets': True,
#                                                                               'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-C_RE_CT_RT_UR': {'allow_urgent_relocation': True,
#                                                                                  'batch_duration': '30',
#                                                                                  'clear_target_list_every_round': True,
#                                                                                  'customer_segmentation': 'C',
#                                                                                  'initial_fleet': '1000',
#                                                                                  'instance_name': 'rebalancingSettings',
#                                                                                  'max_capacity': '4',
#                                                                                  'max_requests': '1000',
#                                                                                  'rebalance': True,
#                                                                                  'reinsert_targets': True,
#                                                                                  'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-C_RE_CT_UR': {'allow_urgent_relocation': True,
#                                                                               'batch_duration': '30',
#                                                                               'clear_target_list_every_round': True,
#                                                                               'customer_segmentation': 'C',
#                                                                               'initial_fleet': '1000',
#                                                                               'instance_name': 'rebalancingSettings',
#                                                                               'max_capacity': '4',
#                                                                               'max_requests': '1000',
#                                                                               'rebalance': True,
#                                                                               'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-C_RE_MO': {'allow_many_to_one': True,
#                                                                            'batch_duration': '30',
#                                                                            'customer_segmentation': 'C',
#                                                                            'initial_fleet': '1000',
#                                                                            'instance_name': 'rebalancingSettings',
#                                                                            'max_capacity': '4',
#                                                                            'max_requests': '1000',
#                                                                            'rebalance': True,
#                                                                            'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-C_RE_MO_RT': {'allow_many_to_one': True,
#                                                                               'batch_duration': '30',
#                                                                               'customer_segmentation': 'C',
#                                                                               'initial_fleet': '1000',
#                                                                               'instance_name': 'rebalancingSettings',
#                                                                               'max_capacity': '4',
#                                                                               'max_requests': '1000',
#                                                                               'rebalance': True,
#                                                                               'reinsert_targets': True,
#                                                                               'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-C_RE_MO_RT_UR': {'allow_many_to_one': True,
#                                                                                  'allow_urgent_relocation': True,
#                                                                                  'batch_duration': '30',
#                                                                                  'customer_segmentation': 'C',
#                                                                                  'initial_fleet': '1000',
#                                                                                  'instance_name': 'rebalancingSettings',
#                                                                                  'max_capacity': '4',
#                                                                                  'max_requests': '1000',
#                                                                                  'rebalance': True,
#                                                                                  'reinsert_targets': True,
#                                                                                  'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-C_RE_MO_UR': {'allow_many_to_one': True,
#                                                                               'allow_urgent_relocation': True,
#                                                                               'batch_duration': '30',
#                                                                               'customer_segmentation': 'C',
#                                                                               'initial_fleet': '1000',
#                                                                               'instance_name': 'rebalancingSettings',
#                                                                               'max_capacity': '4',
#                                                                               'max_requests': '1000',
#                                                                               'rebalance': True,
#                                                                               'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-C_RE_RT': {'batch_duration': '30',
#                                                                            'customer_segmentation': 'C',
#                                                                            'initial_fleet': '1000',
#                                                                            'instance_name': 'rebalancingSettings',
#                                                                            'max_capacity': '4',
#                                                                            'max_requests': '1000',
#                                                                            'rebalance': True,
#                                                                            'reinsert_targets': True,
#                                                                            'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-C_RE_RT_UR': {'allow_urgent_relocation': True,
#                                                                               'batch_duration': '30',
#                                                                               'customer_segmentation': 'C',
#                                                                               'initial_fleet': '1000',
#                                                                               'instance_name': 'rebalancingSettings',
#                                                                               'max_capacity': '4',
#                                                                               'max_requests': '1000',
#                                                                               'rebalance': True,
#                                                                               'reinsert_targets': True,
#                                                                               'simulation_time': '86400'},
#  'IN-rebalancingSettings_BA-30_ST-86400_MR-1000_IF-1000_MC-4_CS-C_RE_UR': {'allow_urgent_relocation': True,
#                                                                            'batch_duration': '30',
#                                                                            'customer_segmentation': 'C',
#                                                                            'initial_fleet': '1000',
#                                                                            'instance_name': 'rebalancingSettings',
#                                                                            'max_capacity': '4',
#                                                                            'max_requests': '1000',
#                                                                            'rebalance': True,
#                                                                            'simulation_time': '86400'}}

# %% [markdown]
# ### Building indexes for multilevel table

# %%
from collections import defaultdict
import math

dict_sl_status = {"MET":"Met", "UNMET":"Unmet"}
filter_sl_status = ["MET"]
instance_attribute = defaultdict(list)
 
# Multilevel service level
for instance_name, dic_request_track in dic_all_request_track.items():
    
    instance_settings = get_instance_settings(instance_name)
    if instance_settings.get('service_rate', '-') == '-':
        continue
    
    column = ('', 'service_rate')
    instance_attribute[column].append(instance_settings['service_rate'])
    column = ('', 'contract_duration')
    instance_attribute[column].append(int(instance_settings['contract_duration']))
    column = ('', 'customer_segmentation')
    instance_attribute[column].append(instance_settings['customer_segmentation'])
    
    for sq_class, sl_status_dic in dic_request_track["service_levels"].items():
        for sl_status, attribute_dic in sl_status_dic.items():
            for attribute, value in attribute_dic.items():
                
                # Filter sl_status
                if sl_status in filter_sl_status:
                    continue
                
                column = (dict_sq_class[sq_class], attribute)
                if(column[1]=="Count"):
                    instance_attribute[column].append(value if not (math.isnan(value) or value==0) else "-")
                else:
                    instance_attribute[column].append(("{:.1f}".format(value/60) if not math.isnan(value) else "-"))

# %%
a = pd.DataFrame.from_dict(dic_all_round_track)
a = a.T
a.to_csv(f"{label}.csv")
a
# Out:
#                                                    A_count    A_dp    A_pk  \
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  128059  123.11  123.11
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  127995   123.1   123.1
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  123299   125.9   125.9
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  126105  125.29  125.29
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  125217  125.48  125.48
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  123001  125.84  125.84
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  127957  122.93  122.93
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  127890  123.42  123.42
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  127957  123.07  123.07
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  123522  126.03  126.03
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  127613  126.12  126.12
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  127570  126.07  126.07
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  123269  125.99  125.99
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  127914  123.31  123.31
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  127998  123.13  123.13
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  128022  123.15  123.15
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  168698  125.41  125.41
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  168825  125.41  125.41
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  152658  128.67  128.67
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  162444  125.74  125.74
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  160428  127.88  127.88
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  151843  129.06  129.06
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  168933   125.4   125.4
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  168902  125.92  125.92
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  169049   125.9   125.9
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  152658  128.52  128.52
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  167750  128.61  128.61
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  167719  128.38  128.38
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  151525  129.44  129.44
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  168352  125.61  125.61
# ...                                                    ...     ...     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   31033  113.99  113.99
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   31552  112.84  112.84
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   31318  112.97  112.97
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   31141  113.52  113.52
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   32321  109.57  109.57
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   32311  109.98  109.98
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   32288  109.75  109.75
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   31073  113.41  113.41
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   31374  113.37  113.37
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   31236  113.79  113.79
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   31078  113.78  113.78
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   32252  110.14  110.14
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   32274  110.67  110.67
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   32339  110.44  110.44
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...       0     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...       0     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...       0     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...       0     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...       0     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...       0     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...       0     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...       0     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...       0     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...       0     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...       0     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...       0     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...       0     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...       0     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...       0     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...       0     NaN     NaN
#
#                                                    A_unmet_slevels B_count  \
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...           16290   33926
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...           16357   33906
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...           20983   33940
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...           18226   33966
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...           19081   33963
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...           21311   33961
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...           16375   33942
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...           16414   33948
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...           16333   33968
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...           20832   33942
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...           16706   33913
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...           16750   33929
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...           21062   33939
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...           16332   33939
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...           16300   33960
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...           16304   33938
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...           43526       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...           43399       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...           59566       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...           49780       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...           51796       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...           60381       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...           43291       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...           43322       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...           43175       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...           59566       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...           44474       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...           44505       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...           60699       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...           43872       0
# ...                                                            ...     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...            2914   33866
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...            2397   33886
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...            2609   33865
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...            2773   33905
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...            1620   33917
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...            1631   33972
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...            1645   33961
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...            2920   33855
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...            2542   33920
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...            2739   33846
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...            2871   33923
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...            1682   33945
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...            1650   33934
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...            1638   33919
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0       0
#
#                                                       B_dp    B_pk  \
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  300.81  156.82
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  300.18  156.12
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  313.95  160.17
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  309.25  159.11
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  311.21  159.54
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   313.9  160.03
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  301.04  156.49
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  299.48  156.48
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  299.77  156.15
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  316.14  160.51
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  306.54  159.33
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  305.37  159.01
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  315.81  160.94
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  300.93  157.25
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  301.21  156.67
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  301.35  156.84
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     NaN
# ...                                                    ...     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   199.2  123.09
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  194.07   120.9
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  196.67  122.12
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  199.51  122.85
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  177.83  114.59
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  178.68  114.76
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  178.46  114.29
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  199.05  122.98
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  197.88  123.03
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  197.67  122.49
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  200.22  123.56
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  179.44  114.79
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  179.73   114.7
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  179.12  114.82
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     NaN
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     NaN
#
#                                                    B_unmet_slevels C_count  \
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...              17   33932
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...              11   33955
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...              12   33990
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...              14   33913
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...              13   33949
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...              12   33939
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...              11   33939
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...              14   33958
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               9   33957
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...              19   33909
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...              13   33979
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...              12   33963
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...              10   33944
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...              12   34027
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               8   33958
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               7   33953
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0       0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0       0
# ...                                                            ...     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...              68  144343
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...              67  144321
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...              70  144361
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...              63  144341
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...              36  144329
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...              29  144280
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...              30  144299
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...              69  144307
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...              52  144335
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...              68  144334
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...              74  144276
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...              35  144308
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...              33  144332
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...              30  144297
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0  212223
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0  212223
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0  212223
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0  212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0  212223
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0  212223
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0  212223
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0  212223
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0  212223
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0  212223
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0  212223
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0  212223
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0  212222
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0  212223
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0  212223
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               0  212223
#
#                                                       C_dp     ...      \
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  406.95     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  406.66     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  433.38     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  421.75     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  428.37     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  432.57     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   405.9     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  407.18     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  407.72     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  436.95     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  418.78     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   413.1     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  436.46     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  410.24     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  406.36     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  407.32     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     NaN     ...
# ...                                                    ...     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  217.24     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  210.04     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  214.78     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  217.12     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  189.15     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  188.45     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   188.4     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  217.66     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  214.18     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  215.66     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  218.23     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  190.22     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  189.55     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   189.2     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  159.56     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  159.08     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  192.84     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  190.78     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  191.19     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  191.94     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  158.56     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  159.06     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  159.43     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  192.33     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   191.5     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  192.39     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   192.5     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  159.49     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  160.03     ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   159.7     ...
#
#                                                    distance_rebalancing  \
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               62.14%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                8.55%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                3.39%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                4.03%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                3.77%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                3.30%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                8.57%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                8.50%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                8.52%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                3.30%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               11.18%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               14.63%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                3.30%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               63.25%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               62.10%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               60.12%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               70.41%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                9.99%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                3.76%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                5.26%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                5.20%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                3.63%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               10.01%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               10.01%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                9.86%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                3.75%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               19.93%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               21.64%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                3.63%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               71.89%
# ...                                                                 ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                3.46%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                3.68%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                3.64%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                3.44%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                9.88%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                9.78%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                9.71%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                3.38%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                4.03%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                3.71%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                3.48%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               54.66%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               55.53%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               52.72%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               50.94%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               10.38%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                3.54%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                3.79%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                3.64%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                3.48%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               10.41%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               10.43%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               10.34%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                3.60%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                3.68%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                3.63%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...                3.45%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               52.46%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               52.18%
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...               51.45%
#
#                                                    distance_total seats_V1  \
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...    1.51092e+06        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         625295        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         551292        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         572702        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         566001        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         549195        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         625826        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         625286        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         624941        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         551460        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         640765        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         665591        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         549446        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...    1.55922e+06        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...    1.51125e+06        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...    1.43406e+06        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     1.9299e+06        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         633112        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         507282        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         559340        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         552418        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         503333        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         634380        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         634199        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         632629        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         507531        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         706339        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         720731        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         502434        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...    2.03208e+06        0
# ...                                                           ...      ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         543858        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         552849        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         548410        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         544458        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         630025        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         629799        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         628455        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         543486        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         552912        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         547560        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         544034        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...    1.25494e+06        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...    1.27679e+06        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...     1.2024e+06        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...    1.15613e+06        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         630745        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         538371        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         540549        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         538995        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         538109        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         631621        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         631817        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         630668        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         538451        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         539824        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         539551        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         537025        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...    1.19274e+06        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...    1.18564e+06        0
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...    1.16699e+06        0
#
#                                                    seats_V2 seats_V3 seats_V4  \
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# ...                                                     ...      ...      ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...        0        0     4000
#
#                                                    serviced total_requests  \
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   92.32%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   92.29%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   90.11%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   91.41%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   91.00%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   89.95%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   92.28%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   92.26%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   92.30%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   90.18%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   92.12%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   92.10%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   90.07%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   92.30%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   92.32%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   92.31%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   79.49%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   79.55%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   71.93%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   76.54%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   75.59%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   71.55%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   79.60%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   79.59%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   79.66%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   71.93%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   79.04%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   79.03%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   71.40%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   79.33%         212224
# ...                                                     ...            ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   98.59%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   98.84%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   98.74%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   98.66%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   99.22%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   99.22%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   99.21%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   98.59%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   98.78%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   98.68%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   98.61%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   99.19%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   99.21%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...   99.21%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  100.00%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  100.00%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  100.00%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  100.00%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  100.00%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  100.00%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  100.00%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  100.00%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  100.00%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  100.00%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  100.00%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  100.00%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  100.00%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  100.00%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  100.00%         212224
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...  100.00%         212224
#
#                                                    total_runtime total_seats
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         11.06        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          5.40        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.51        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          2.96        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.23        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.68        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          4.34        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          4.15        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...         12.57        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.55        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.85        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.50        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.64        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          9.09        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          6.50        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          8.99        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          5.40        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.02        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          2.99        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.44        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.59        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.21        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.31        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.94        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.11        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.03        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.39        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.49        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.08        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          5.86        4000
# ...                                                          ...         ...
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.24        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          5.11        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          4.52        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          4.38        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.97        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          4.32        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          4.19        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.91        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          4.16        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.87        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.37        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          5.27        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          5.16        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          5.82        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          5.43        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          4.13        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.37        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.11        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.09        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.23        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.53        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.49        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.71        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.54        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.13        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.08        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          3.43        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          4.41        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          4.49        4000
# IN-rebalancingSettings_BA-30_ST-86400_MR-1000_I...          4.93        4000
#
# [96 rows x 31 columns]

# %% [markdown]
# ### Table: What is the service level (pickup delay) of the users lying outside SQ-class service rate?

# %%
a = pd.DataFrame.from_dict(instance_attribute)

# Establishing category order and alias dictionaries
dict_segmentation = {"AA":"B+", "BB":"S+", "CC":"L+", "A":"B", "B":"S", "C":"L"}
category_segmentation = pd.api.types.CategoricalDtype(categories=["B+", "S+", "L+", "B", "S", "L"], ordered=True)

dict_contract_duration = {3600:"1h", 0:"Single-ride", 10800:"3h"}
category_contract_duration = pd.api.types.CategoricalDtype(categories=["Single-ride", "1h", "3h"], ordered=True)

dict_service_rate = {"S1":"SR1", "S2":"SR2", "S3":"SR3"}
category_service_rate = pd.api.types.CategoricalDtype(categories=["SR1", "SR2", "SR3"], ordered=True)

key_sr = ('', 'service_rate') # (S1, S2, S3)
key_cs = ('', 'customer_segmentation') # (A, AA, BB, etc.)
key_cd = ('', 'contract_duration') #(0, 3600, 18000)

# Filtering data
a = a[a[key_cs].isin(["AA",
                      "BB",
                      "CC"])]

# Renaming data and applying aliases
a[key_cs] = a[key_cs].map(lambda e:dict_segmentation[e])
a[key_cs] = a[key_cs].astype(category_segmentation)

a[key_cd] = a[key_cd].map(lambda e:dict_contract_duration[e])
a[key_cd] = a[key_cd].astype(category_contract_duration)

a[key_sr] = a[key_sr].map(lambda e:dict_service_rate[e])
a[key_sr] = a[key_sr].astype(category_service_rate)

a = a.sort_values(by=[key_sr, key_cs, key_cd])
a = a.set_index([key_sr, key_cs, key_cd])

a.index.names = ["Service rate",
                 "Segmentation scenario",
                 "Contract duration"]

a

# Getting latex table
# print(a.to_latex(multicolumn=True, multirow=True))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\env_slevels\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('', 'customer_segmentation')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-093af87edccc> in <module>
#      16
#      17 # Filtering data
# ---> 18 a = a[a[key_cs].isin(["AA",
#      19                       "BB",
#      20                       "CC"])]
#
# ~\Anaconda3\envs\env_slevels\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Anaconda3\envs\env_slevels\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\envs\env_slevels\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\Anaconda3\envs\env_slevels\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\envs\env_slevels\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('', 'customer_segmentation')
