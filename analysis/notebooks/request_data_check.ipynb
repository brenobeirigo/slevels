# %%
import pandas as pd

path_requests = "tripdata_ids_2011-02-01_000000_2011-02-07_235959.csv"
folder = "C:/Users/LocalAdmin/OneDrive/leap_forward/street_network_server/tenv/data/out/manhattan/tripdata/ids/"

df = pd.read_csv(folder + path_requests, parse_dates=True)

# %%
earliest = "2011-02-01 18:00:00"
cut_df =df[df["pickup_datetime"]>=earliest]
cut_df.head(20)
# Out:
#             pickup_datetime  passenger_count  pk_id  dp_id  pickup_longitude  \
# 150970  2011-02-01 18:00:00                1   2016    943        -73.962300
# 150971  2011-02-01 18:00:00                2   4024   2363        -73.996907
# 150972  2011-02-01 18:00:00                1   1325   1132        -73.985700
# 150973  2011-02-01 18:00:00                1   2105   1575        -73.985840
# 150974  2011-02-01 18:00:00                1   3158   3155        -74.010002
# 150975  2011-02-01 18:00:00                6   2647   1832        -73.981120
# 150976  2011-02-01 18:00:00                1   2818    521        -73.954948
# 150977  2011-02-01 18:00:00                1   2692   2665        -73.975245
# 150978  2011-02-01 18:00:00                1   2980   3016        -73.976657
# 150979  2011-02-01 18:00:00                5    792    331        -74.000070
# 150980  2011-02-01 18:00:00                1   3840   2449        -73.981817
# ...
