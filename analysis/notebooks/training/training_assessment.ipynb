# %%
import pandas as pd
# filepath = "IN-RELU1H128LSTM_ST-1800_RH-1800_BA-60_MR-10_PR-0.200_IF-100_MC-4_CS-BB_HC-150_CD-0_VH_RE-OP.csv"
# filepath = "IN-BATCH500RELU1H128LSTM_ST-1800_RH-1800_BA-60_MR-10_PR-0.200_IF-100_MC-4_CS-BB_HC-150_CD-0_VH_RE-OP.csv"
# filepath = "IN-RELU1H128LSTMEMBEDSIMPLE_ST-1800_RH-1800_BA-60_MR-10_PR-0.050_IF-50_MC-4_CS-BB_HC-150_CD-0_VH_RE-OP.csv"
# filepath = "IN-RELU1H128LSTMEMBEDSIMPLE100weights_ST-1800_RH-1800_BA-60_MR-10_PR-0.050_IF-50_MC-4_CS-BB_HC-150_CD-0_VH_RE-OP.csv"
# filepath = "IN-RELU1H128LSTMEMBEDSIMPLE100weights17_ST-1800_RH-1800_BA-60_MR-10_PR-0.050_IF-50_MC-4_CS-BB_HC-150_CD-0_VH_RE-OP2.csv"
# filepath = "IN-RELU1H128LSTMEMBEDSIMPLE100weights17faster_ST-1800_RH-1800_BA-60_MR-10_PR-0.050_IF-50_MC-4_CS-BB_HC-150_CD-0_VH_RE-OP.csv"
# filepath = "IN-RELU1H128LSTMEMBEDSIMPLE100weightsSmallLogsavexp2_ST-7200_RH-7200_BA-60_MR-10_PR-0.020_IF-20_MC-4_CS-BB_HC-150_CD-0_VH_RE-OP.csv"
# filepath = "IN-TESTREP4_STARTZONESLFIX_ST-3600_RH-3600_BA-60_MR-10_PR-0.010_IF-20_MC-4_CS-BB_HC-150_CD-0_VH_RE-OP.csv"
# filepath = "IN-RELU1H128LSTMEMBEDW100_ST-3600_RH-3600_BA-60_MR-10_PR-0.050_IF-50_MC-4_CS-BB_HC-150_CD-0_VH_RE-OP.csv"
# filepath = "IN-TESTMEM_ST-3600_RH-3600_BA-60_MR-10_PR-0.080_IF-20_MC-4_CS-BB_HC-150_CD-0_VH_RE-OP.csv"

# 2 hidden layers with ELU discount = 0.1
#filepath = "IN-ELUX2REBALFAST2_ST-3600_RH-3600_BA-60_MR-10_PR-0.080_IF-20_MC-4_CS-BB_HC-150_CD-0_VH_RE-OP.csv"
#filepath = "e.csv"
# 2 hidden layers with RELU discount = 0.1
#filepath = "IN-RELUX2REBALFAST205_ST-3600_RH-3600_BA-60_MR-10_PR-0.080_IF-20_MC-4_CS-BB_HC-150_CD-0_VH_RE-OP.csv"

# 2 hidden layers with RELU discount = 0.5
#filepath = "IN-RELUX2REBALFAST205_ST-3600_RH-3600_BA-60_MR-10_PR-0.080_IF-20_MC-4_CS-BB_HC-150_CD-0_VH_RE-OP.csv"

#filepath = "IN-TESTREP4_STARTZONESMALL128_ST-3600_RH-3600_BA-60_MR-10_PR-0.010_IF-20_MC-4_CS-BB_HC-150_CD-0_VH_RE-OP.csv"

# RELU1H128LSTMEMBEDSIMPLE100weights17fasterdensenet
#filepath = "IN-RELU1H128LSTMEMBEDW100_ST-3600_RH-3600_BA-60_MR-10_PR-0.050_IF-50_MC-4_CS-BB_HC-150_CD-0_VH_RE-OP.csv"
# filepath = "test"
filepath1 = "result/relu05.csv"
filepath2 = "result/relu10.csv"
filepath3 = "result/elu01.csv"

filepath3 = "IN-RELUSaved_ST-3600_RH-3600_BA-60_MR-10_PR-0.080_IF-20_MC-4_CS-BB_HC-150_CD-0_VH_RE-OP.csv"
df1 = pd.read_csv(filepath1, sep=';')
df1["label"] = "Relu 0.5"
df2 = pd.read_csv(filepath2, sep=';')
df2["label"] = "Relu 0.1"
df3 = pd.read_csv(filepath3, sep=';')
df3["label"] = "Elu 0.1"
df = pd.concat([df1, df2, df3])
df.tail()
# Out:
#        type                             config                method  episode  \
# 3803  train  RS-1000_BA-32_BU-500_TAR-30_FR-30         _OPT-JAVIERVF      762
# 3804  train  RS-1000_BA-32_BU-500_TAR-30_FR-30         _OPT-JAVIERVF      762
# 3805  train  RS-1000_BA-32_BU-500_TAR-30_FR-30         _OPT-JAVIERVF      763
# 3806  train  RS-1000_BA-32_BU-500_TAR-30_FR-30         _OPT-JAVIERVF      763
# 3807  train  RS-1000_BA-32_BU-500_TAR-30_FR-30         _OPT-JAVIERVF      763
#
#                  earliest  n_vehicles  n_requests  n_finished  service_rate  \
# 3803  2019-02-07 17:00:00          20         907         679        0.7486
# 3804  2019-02-08 17:00:00          20         956         707        0.7395
# 3805  2019-02-04 17:00:00          20         843         678        0.8043
# 3806  2019-02-05 17:00:00          20         864         675        0.7813
# 3807  2019-02-06 17:00:00          20         941         702        0.7460
#
# ...

# %%
df[df["label"] == "Relu 0.5"]
# Out:
#        type                             config                method  episode  \
# 0      test                                  -           _OPT-JAVIER        0
# 1      test                                  -           _OPT-JAVIER        1
# 2      test                                  -           _OPT-JAVIER        2
# 3      test                                  -           _OPT-JAVIER        3
# 4      test                                  -           _OPT-JAVIER        4
# ...     ...                                ...                   ...      ...
# 2569  train  RS-1000_BA-32_BU-500_TAR-30_FR-30         _OPT-JAVIERVF      511
# 2570  train  RS-1000_BA-32_BU-500_TAR-30_FR-30         _OPT-JAVIERVF      512
# 2571  train  RS-1000_BA-32_BU-500_TAR-30_FR-30         _OPT-JAVIERVF      512
# 2572  train  RS-1000_BA-32_BU-500_TAR-30_FR-30         _OPT-JAVIERVF      512
# 2573  train  RS-1000_BA-32_BU-500_TAR-30_FR-30         _OPT-JAVIERVF      512
#
# ...

# %%
df[df.columns[-6:]].plot()

# %%
df[df.columns[-6:]].plot()

# %% [raw]
# len(df), df

# %%
a = ['-', 'RS-5_BA-3_BU-10_TAR-1_FR-2']
filter_config = df["config"] == a[0]
df[filter_config]

# %%
df_train = df[df["type"]=="train"]

# %%
df_train.columns
# Out:
# Index(['type', 'config', 'method', 'episode', 'earliest', 'n_vehicles',
#        'n_requests', 'n_finished', 'service_rate', 'max_rounds', 'round_count',
#        'total_delay', 'distance_empty', 'distance_loaded', 'runtime_sec',
#        'At origin', 'Rebalancing', 'Stopped rebalancing', 'Cruising to pickup',
#        'Servicing', 'Parked last destination', 'label'],
#       dtype='object')

# %%
import seaborn as sns
sns.set_context("talk")
fig, ax = plt.subplots(figsize=(10,8))
df1 = df_train[df_train["label"] == "Relu 0.5"]["service_rate"]
#df1.plot(label="RElu 0.5", legend=True)
df2 = df_train[df_train["label"] == "Relu 0.1"]["service_rate"]
#df2.plot(label="RElu 0.1", legend=True)
df3 = df_train[df_train["label"] == "Elu 0.1"]["service_rate"]
#df3.plot(label="ELU 0.1", legend=True)

window = 500
df1.rolling(window).mean()
conf.plot()

plt.plot(np.arange(0,2500), df1[0:2500].rolling(window).mean().values.astype(float), label="RELu (discount=0.5)")
plt.plot(np.arange(0,2500), df2[0:2500].rolling(window).mean().values.astype(float), label="RELu (discount=0.1)")
plt.plot(np.arange(0,2500), df3[0:2500].rolling(window).mean().values.astype(float), label="ELU (discount=0.1)")
        
plt.xlim([500, 2500])
plt.legend()
plt.xlabel("Iterations")
plt.ylabel("Service rate")
plt.savefig("/mnt/d/train.png", dpi=300, bbox_inches="tight")

# %% [markdown]
# ## Moving average training

# %%
window = 100
import numpy as np
import matplotlib.pyplot as plt
config_labels = list(map(str,set(df["label"].values)))
print(config_labels)
for training_settings in config_labels:
    print("cl = ", training_settings, training_settings == "-")
    filter_label = df_train["label"] == training_settings
    print(filter_label.tail())
    conf=df_train[filter_config]["service_rate"]
    print(df_train.tail())
    clavg = conf.rolling(window).mean()
    
    if len(conf) > 0:
        #plt.plot(np.arange(0,len(conf)), conf.values.astype(float), label=training_settings)
        plt.plot(np.arange(0,len(clavg)), clavg.values.astype(float), label=training_settings+"(avg)")
        
plt.legend()
#plt.ylim(0,1)
# Out:
# ['Elu 0.1', 'Relu 0.5', 'Relu 0.1']
# cl =  Elu 0.1 False
# 3803    True
# 3804    True
# 3805    True
# 3806    True
# 3807    True
# Name: label, dtype: bool
# /tmp/ipykernel_14691/2313321826.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   conf=df_train[filter_config]["service_rate"]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [39], in <cell line: 6>()
#       8 filter_label = df_train["label"] == training_settings
#       9 print(filter_label.tail())
# ---> 10 conf=df_train[filter_config]["service_rate"]
#      11 print(df_train.tail())
#      12 clavg = conf.rolling(window).mean()
#
# File /mnt/d/projects/dev/mobio/envmobio/lib/python3.8/site-packages/pandas/core/frame.py:3449, in DataFrame.__getitem__(self, key)
#    3447 # Do we have a (boolean) 1d indexer?
#    3448 if com.is_bool_indexer(key):
# ...

# %% [markdown]
# ## Testing performance

# %%
import numpy as np
import matplotlib.pyplot as plt
methods = list(map(str,set(df["method"].values)))
print(methods)

df_test = pd.read_csv("IN-RELUSaved_ST-3600_RH-3600_BA-60_MR-10_PR-0.080_IF-20_MC-4_CS-BB_HC-150_CD-0_VH_RE-OP.csv", sep=';')
metrics = ["service_rate", "total_delay"]

df_test
d
# Out:
# ['         _OPT-JAVIER', '       _OPT-JAVIERVF']
#     type config                method  episode             earliest  \
# 0   test      -         _OPT-JAVIERVF        0  2019-02-20 17:00:00
# 1   test      -         _OPT-JAVIERVF        1  2019-02-20 17:00:00
# 2   test      -         _OPT-JAVIERVF        2  2019-02-20 17:00:00
# 3   test      -         _OPT-JAVIERVF        3  2019-02-20 17:00:00
# 4   test      -         _OPT-JAVIERVF        4  2019-02-20 17:00:00
# 5   test      -         _OPT-JAVIERVF        5  2019-02-20 17:00:00
# 6   test      -         _OPT-JAVIERVF        6  2019-02-20 17:00:00
# 7   test      -         _OPT-JAVIERVF        7  2019-02-20 17:00:00
# 8   test      -         _OPT-JAVIERVF        8  2019-02-20 17:00:00
# 9   test      -         _OPT-JAVIERVF        9  2019-02-20 17:00:00
# 10  test      -           _OPT-JAVIER        0  2019-02-20 17:00:00
# 11  test      -           _OPT-JAVIER        1  2019-02-20 17:00:00
# ...

# %%
fig, ax = plt.subplots(figsize=(10, 5))
plt.plot(np.arange(10), df_test[0:10]["service_rate"], label="Matching + VFs")
plt.plot(np.arange(10), df_test[10:20]["service_rate"], label="Matching")
plt.xlabel("Instance")
plt.ylabel("Service rate")
plt.xticks(np.arange(0,10), np.arange(1,11))
plt.legend()
plt.savefig("/mnt/d/fig.png", dpi=300, bbox_inches="tight")

# %%
dff = df_test[10:20][df_test.columns[-6:]]/(20*75)
fig, ax = plt.subplots(figsize=(10, 5))
dff.plot(kind="bar", stacked=True, ax=ax)
# ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),
#           fancybox=False, shadow=False, ncol=6)
plt.legend(bbox_to_anchor=(1.05, 1))
ax.set_xticks(np.arange(0, 10), np.arange(1, 11))
plt.xlabel("Instance")
plt.ylabel("Avg. fleet status (per time step)")
plt.ylim(0,1)
plt.savefig("/mnt/d/status.png", dpi=300, bbox_inches="tight")

# %%
df_test[10:20][df_test[10:20].columns[-6:]].plot()
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(1,2, figsize=(15,10))
ax_idx = 0
for metric in metrics:
    for method in methods:
        filter_method = df_test["method"] == method
        conf=df_test[filter_method][metric]

        print(method, conf.mean())
        if len(conf) > 0:
            ax[ax_idx].bar(method, conf.mean())
            ax[ax_idx].legend()
    
    ax_idx = ax_idx + 1


        
ax[0].set_xlabel("Method")
ax[0].set_ylabel("Avg. service rate")

ax[1].set_xlabel("Method")
ax[1].set_ylabel("Avg. delay")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#          _OPT-JAVIER 0.8796999999999999
#        _OPT-JAVIERVF 0.81556
#          _OPT-JAVIER 143036.2
#        _OPT-JAVIERVF 147260.7
# Text(0, 0.5, 'Avg. delay')

# %%
## How many users appear
